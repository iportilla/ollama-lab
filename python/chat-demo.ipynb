# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /Users/watson/anaconda3/lib/python3.10/site-packages (2.31.0)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests) (3.4)

# %%
# !pip install gradio
# Out:
# Requirement already satisfied: gradio in /Users/watson/anaconda3/lib/python3.10/site-packages (4.8.0)
# Requirement already satisfied: typer[all]<1.0,>=0.9 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.9.0)
# Requirement already satisfied: jinja2<4.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (3.1.2)
# Requirement already satisfied: matplotlib~=3.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (3.8.1)
# Requirement already satisfied: importlib-resources<7.0,>=1.3 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (6.1.1)
# Requirement already satisfied: ffmpy in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.3.1)
# Requirement already satisfied: pandas<3.0,>=1.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (1.5.3)
# Requirement already satisfied: pyyaml<7.0,>=5.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (6.0.1)
# Requirement already satisfied: httpx in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.23.3)
# Requirement already satisfied: uvicorn>=0.14.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.22.0)
# Requirement already satisfied: pillow<11.0,>=8.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (9.5.0)
# Requirement already satisfied: gradio-client==0.7.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.7.1)
# Requirement already satisfied: markupsafe~=2.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (2.1.1)
# Requirement already satisfied: tomlkit==0.12.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.12.0)
# Requirement already satisfied: pydantic>=2.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (2.5.2)
# Requirement already satisfied: python-multipart in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.0.6)
# Requirement already satisfied: packaging in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (22.0)
# Requirement already satisfied: pydub in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.25.1)
# Requirement already satisfied: huggingface-hub>=0.14.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.17.3)
# Requirement already satisfied: typing-extensions~=4.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (4.8.0)
# Requirement already satisfied: aiofiles<24.0,>=22.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (23.2.1)
# Requirement already satisfied: numpy~=1.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (1.23.5)
# Requirement already satisfied: orjson~=3.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (3.9.10)
# Requirement already satisfied: fastapi in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (0.104.1)
# Requirement already satisfied: semantic-version~=2.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (2.10.0)
# Requirement already satisfied: altair<6.0,>=4.2.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (4.2.2)
# Requirement already satisfied: requests~=2.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio) (2.31.0)
# Requirement already satisfied: fsspec in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio-client==0.7.1->gradio) (2023.10.0)
# Requirement already satisfied: websockets<12.0,>=10.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from gradio-client==0.7.1->gradio) (11.0.3)
# Requirement already satisfied: jsonschema>=3.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (4.17.3)
# Requirement already satisfied: entrypoints in /Users/watson/anaconda3/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.4)
# Requirement already satisfied: toolz in /Users/watson/anaconda3/lib/python3.10/site-packages (from altair<6.0,>=4.2.0->gradio) (0.12.0)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (4.64.1)
# Requirement already satisfied: filelock in /Users/watson/anaconda3/lib/python3.10/site-packages (from huggingface-hub>=0.14.0->gradio) (3.12.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.4.4)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (4.25.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (3.0.9)
# Requirement already satisfied: cycler>=0.10 in /Users/watson/anaconda3/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/watson/anaconda3/lib/python3.10/site-packages (from matplotlib~=3.0->gradio) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from pandas<3.0,>=1.0->gradio) (2022.7)
# Requirement already satisfied: annotated-types>=0.4.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (0.5.0)
# Requirement already satisfied: pydantic-core==2.14.5 in /Users/watson/anaconda3/lib/python3.10/site-packages (from pydantic>=2.0->gradio) (2.14.5)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests~=2.0->gradio) (2023.11.17)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests~=2.0->gradio) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests~=2.0->gradio) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from requests~=2.0->gradio) (1.26.18)
# Requirement already satisfied: click<9.0.0,>=7.1.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (8.1.7)
# Requirement already satisfied: shellingham<2.0.0,>=1.3.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (1.5.4)
# Requirement already satisfied: colorama<0.5.0,>=0.4.3 in /Users/watson/anaconda3/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (0.4.4)
# Requirement already satisfied: rich<14.0.0,>=10.11.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from typer[all]<1.0,>=0.9->gradio) (13.3.5)
# Requirement already satisfied: h11>=0.8 in /Users/watson/anaconda3/lib/python3.10/site-packages (from uvicorn>=0.14.0->gradio) (0.14.0)
# Requirement already satisfied: anyio<4.0.0,>=3.7.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from fastapi->gradio) (3.7.1)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from fastapi->gradio) (0.27.0)
# Requirement already satisfied: httpcore<0.17.0,>=0.15.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from httpx->gradio) (0.16.3)
# Requirement already satisfied: rfc3986[idna2008]<2,>=1.3 in /Users/watson/anaconda3/lib/python3.10/site-packages (from httpx->gradio) (1.5.0)
# Requirement already satisfied: sniffio in /Users/watson/anaconda3/lib/python3.10/site-packages (from httpx->gradio) (1.2.0)
# Requirement already satisfied: exceptiongroup in /Users/watson/anaconda3/lib/python3.10/site-packages (from anyio<4.0.0,>=3.7.1->fastapi->gradio) (1.2.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (22.1.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from jsonschema>=3.0->altair<6.0,>=4.2.0->gradio) (0.18.0)
# Requirement already satisfied: six>=1.5 in /Users/watson/anaconda3/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib~=3.0->gradio) (1.16.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/watson/anaconda3/lib/python3.10/site-packages (from rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (2.15.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/watson/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich<14.0.0,>=10.11.0->typer[all]<1.0,>=0.9->gradio) (0.1.2)
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 715, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 416, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 244, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1282, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1328, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1277, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1037, in _send_output
#     self.send(msg)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 975, in send
#     self.connect()
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x154785e10>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 799, in urlopen
#     retries = retries.increment(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x154785e10>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/queueing.py", line 456, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/route_utils.py", line 232, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/blocks.py", line 1522, in process_api
#     result = await self.call_function(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/blocks.py", line 1144, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/utils.py", line 674, in wrapper
#     response = f(*args, **kwargs)
#   File "/var/folders/2c/8q3v_xr161z5f8xdvkqpxpg40000gn/T/ipykernel_6883/2259904963.py", line 25, in generate_response
#     response = requests.post(url, headers=headers, data=json.dumps(data))
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x154785e10>: Failed to establish a new connection: [Errno 61] Connection refused'))
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# ConnectionRefusedError: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 715, in urlopen
#     httplib_response = self._make_request(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 416, in _make_request
#     conn.request(method, url, **httplib_request_kw)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 244, in request
#     super(HTTPConnection, self).request(method, url, body=body, headers=headers)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1282, in request
#     self._send_request(method, url, body, headers, encode_chunked)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1328, in _send_request
#     self.endheaders(body, encode_chunked=encode_chunked)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1277, in endheaders
#     self._send_output(message_body, encode_chunked=encode_chunked)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 1037, in _send_output
#     self.send(msg)
#   File "/Users/watson/anaconda3/lib/python3.10/http/client.py", line 975, in send
#     self.connect()
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 205, in connect
#     conn = self._new_conn()
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <urllib3.connection.HTTPConnection object at 0x154785e10>: Failed to establish a new connection: [Errno 61] Connection refused
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/adapters.py", line 486, in send
#     resp = conn.urlopen(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/connectionpool.py", line 799, in urlopen
#     retries = retries.increment(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/urllib3/util/retry.py", line 592, in increment
#     raise MaxRetryError(_pool, url, error or ResponseError(cause))
# urllib3.exceptions.MaxRetryError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x154785e10>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/queueing.py", line 456, in call_prediction
#     output = await route_utils.call_process_api(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/route_utils.py", line 232, in call_process_api
#     output = await app.get_blocks().process_api(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/blocks.py", line 1522, in process_api
#     result = await self.call_function(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/blocks.py", line 1144, in call_function
#     prediction = await anyio.to_thread.run_sync(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/anyio/to_thread.py", line 33, in run_sync
#     return await get_asynclib().run_sync_in_worker_thread(
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 877, in run_sync_in_worker_thread
#     return await future
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/anyio/_backends/_asyncio.py", line 807, in run
#     result = context.run(func, *args)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/utils.py", line 674, in wrapper
#     response = f(*args, **kwargs)
#   File "/var/folders/2c/8q3v_xr161z5f8xdvkqpxpg40000gn/T/ipykernel_6883/2259904963.py", line 25, in generate_response
#     response = requests.post(url, headers=headers, data=json.dumps(data))
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/api.py", line 115, in post
#     return request("post", url, data=data, json=json, **kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/api.py", line 59, in request
#     return session.request(method=method, url=url, **kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/sessions.py", line 589, in request
#     resp = self.send(prep, **send_kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/sessions.py", line 703, in send
#     r = adapter.send(request, **kwargs)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/requests/adapters.py", line 519, in send
#     raise ConnectionError(e, request=request)
# requests.exceptions.ConnectionError: HTTPConnectionPool(host='localhost', port=11434): Max retries exceeded with url: /api/generate (Caused by NewConnectionError('<urllib3.connection.HTTPConnection object at 0x154785e10>: Failed to establish a new connection: [Errno 61] Connection refused'))
#
# The above exception was the direct cause of the following exception:
#
# Traceback (most recent call last):
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/queueing.py", line 501, in process_events
#     response = await self.call_prediction(awake_events, batch)
#   File "/Users/watson/anaconda3/lib/python3.10/site-packages/gradio/queueing.py", line 465, in call_prediction
#     raise Exception(str(error) if show_error else None) from error
# Exception: None

# %%
import requests
import json
import gradio as gr

# %%
url = "http://localhost:11434/api/generate"

headers = {
        'Content-Type': 'application/json',
    }

conversation_history = []

# %%
def generate_response(prompt):
        conversation_history.append(prompt)

        full_prompt = "\n".join(conversation_history)

        data = {
            #"model": "mistral",
            "model": "orca-mini",
            "stream": False,
            "prompt": full_prompt,
        }

        response = requests.post(url, headers=headers, data=json.dumps(data))

        if response.status_code == 200:
            response_text = response.text
            data = json.loads(response_text)
            actual_response = data["response"]
            conversation_history.append(actual_response)
            return actual_response
        else:
            print("Error:", response.status_code, response.text)
            return None

# %%
iface = gr.Interface(
        fn=generate_response,
        #inputs=gr.inputs.Textbox(lines=2, placeholder="Enter your prompt here..."),
        inputs=gr.Textbox(lines=2, placeholder="Enter your prompt here..."),
        outputs="text"
    )

# %%
iface.launch(share=True)
# Out:
# Running on local URL:  http://127.0.0.1:7860
# Running on public URL: https://98a3cb38a4a2655806.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://98a3cb38a4a2655806.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
